# %%
import cv2

print('Hello, OpenCV', cv2.__version__)
# Out:
# Hello, OpenCV 4.7.0

# %%
import sys
import cv2

img = cv2.imread('cat.bmp')

if img is None:
    print('image load failed!')
    sys.exit()
    
cv2.namedWindow('image')
cv2.imshow('image', img)
cv2.waitKey()
cv2.destroyWindow('image')

# %%
import sys
import cv2

img = cv2.imread('cat.bmp', cv2.IMREAD_GRAYSCALE)

if img is None:
    print('image load failed!')
    sys.exit()
    
cv2.namedWindow('image')
cv2.imshow('image', img)
cv2.waitKey()
cv2.destroyWindow('image')

# %%
import sys
import cv2

img = cv2.imread('cat.bmp', cv2.IMREAD_GRAYSCALE)

if img is None:
    print('image load failed!')
    sys.exit()

cv2.imwrite('cat.png', img)
    
cv2.namedWindow('image')
cv2.imshow('image', img)
cv2.waitKey()
cv2.destroyWindow('image')

# %%
import sys
import cv2

img = cv2.imread('cat.bmp', cv2.IMREAD_GRAYSCALE)

if img is None:
    print('image load failed!')
    sys.exit()

cv2.imwrite('cat.png', img)
    
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image', img)
cv2.waitKey()
cv2.destroyWindow('image')

# %% [markdown]
# ---------------

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages (3.6.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: numpy>=1.19 in c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages (from matplotlib) (1.24.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\kangminju\miniconda3\envs\ds_study\lib\site-packages)

# %%
import matplotlib.pyplot as plt
import cv2

# 컬러 영상 출력
imgRGB = cv2.imread('cat.bmp')
imgRGB = cv2.cvtColor(imgRGB, cv2.COLOR_BGR2RGB)

plt.axis('off')
plt.imshow(imgRGB)
plt.show()

# 그레이스케일 영상 출력
imgGray = cv2.imread('cat.bmp', cv2.IMREAD_GRAYSCALE)

plt.axis('off')
plt.imshow(imgGray, cmap='gray')
plt.show()

# 두 개의 영상을 함께 출력
plt.subplot(121), plt.axis('off'), plt.imshow(imgRGB)
plt.subplot(122), plt.axis('off'), plt.imshow(imgGray, cmap='gray')
plt.show()
